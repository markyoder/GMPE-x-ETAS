# %%
# %load_ext autoreload
# %autoreload 2
#
# %matplotlib inline

# %%
import etas_to_gmp
import os
#
etas_src  = 'etas_src/nepal_etas_20150507_b.xyz'
fname = os.path.split(etas_src)[-1]
fname = fname.replace('_etas_', '_gmpe_')
#
fout_name = os.path.join(os.getenv('HOME'), 'Dropbox/Research/GMPE/nepal/', fname)
print('exporting to: {}'.format(fout_name))
#
# Out:
# exporting to: /home/myoder/Dropbox/Research/GMPE/nepal/nepal_gmpe_20150507_b.xyz

# %%
etas_size = (50,50)
gmp_size  = (50,50)

etas_size = None
gmp_size  = None
aa = etas_to_gmp.etas_to_GM(etas_src=etas_src, fname_out=fout_name, etas_size=etas_size, gmp_size=gmp_size,
                            fignum=0, maxMag=7.0, verbose=True)
# Out:
# exporting data to: /home/myoder/Dropbox/Research/GMPE/nepal/nepal_gmpe_20150507_b.xyz
# open etas_src file:  etas_src/nepal_etas_20150507_b.xyz
# len(X) = 100
# len(Y) = 100
# Total size = 10000
# ETAS_array, size: 10000, shape: (10000,)/(100, 100)
# shapes:  (100,) (100,) (100, 100) 10000
# GMP_size: (100, 100)/(100, 100)
# data handle fetched...
#  no file.
# Elapsed time:  5837.782252550125
# len(X) = 100
# len(Y) = 100
# Total size = 10000
# saving image to: /home/myoder/Dropbox/Research/GMPE/nepal/nepal_gmpe_20150507_b.png

# %%
aa[0:5]
# Out:
# rec.array([(79.698, 23.175, 4.604994707396301e-10),
#  (79.79799999999999, 23.175, 1.3019017001922872e-09),
#  (79.89799999999998, 23.175, 3.660366248905937e-09),
#  (79.99799999999998, 23.175, 1.0220903436758151e-08),
#  (80.09799999999997, 23.175, 2.8292014590620018e-08)],
#           dtype=[('x', '>f8'), ('y', '>f8'), ('z', '>f8')])
